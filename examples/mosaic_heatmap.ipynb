# %%
# Set the notebook to automatically reload modules before executing code
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
from qqgjyx import QQ

import matplotlib.pyplot as plt
QQ.style()

# %% [markdown]
# # Mosaic Heatmap
# ---

# %% [markdown]
# ## Importing Packages

# %%
import numpy as np
import seaborn as sns
from mheatmap import mosaic_heatmap

# %% [markdown]
# ## Example

# %%
# Create a sample 4x4 confusion matrix with some interesting patterns
conf_mat = np.array([
    [85, 10, 5,   0],  # High accuracy for class 0 
    [0,  50, 30,  0],  # Some confusion between classes 1 and 2
    [0,   0,  0,  0],  # Empty row representing unused class
    [0,   0,  0, 100]  # Perfect classification for class 3
])

# Create a figure with two subplots side by side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 3.5))

# Plot traditional heatmap using seaborn
sns.heatmap(conf_mat, fmt="d", cmap="YlGnBu", ax=ax1)
ax1.set_title("Normal Heatmap")  # Medium gray
ax1.xaxis.set_ticks_position('top')

# Plot mosaic heatmap using mheatmap
mosaic_heatmap(conf_mat, fmt="d", cmap="YlGnBu", ax=ax2)
ax2.set_title("Mosaic Heatmap")  # Medium gray
ax2.xaxis.set_ticks_position('top')

plt.show()
